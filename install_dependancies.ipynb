# %% [markdown]
# ## Installing Dependencies
# install the dependecies one after another and then restart the PC

# %%
# !pip install neura-dual-quaternions
# !pip install numpy
# !pip install ipympl
# !pip install matplotlib
# !pip install ipywidgets
# !pip install "jupyterlab_rise<0.40.0"
# Out:
# ...
#   Using cached neura_dual_quaternions-0.0.4-py3-none-any.whl.metadata (505 bytes)
# ...
#   Using cached numpy-2.0.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Using cached neura_dual_quaternions-0.0.4-py3-none-any.whl (7.5 kB)
# Using cached numpy-2.0.0-cp311-cp311-win_amd64.whl (16.5 MB)
# ...
#   Using cached ipympl-0.9.4-py3-none-any.whl.metadata (8.7 kB)
# ...
#   Using cached ipywidgets-8.1.3-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached matplotlib-3.9.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached pillow-10.4.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached widgetsnbextension-4.0.11-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached jupyterlab_widgets-3.0.11-py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.53.0-cp311-cp311-win_amd64.whl.metadata (165 kB)
# ...

# %%
pip install --upgrade jupyterlab_rise
# Out:
# ...
#   Using cached jupyterlab_rise-0.42.0-py3-none-any.whl.metadata (7.0 kB)
# ...
# Using cached jupyterlab_rise-0.42.0-py3-none-any.whl (11.8 MB)
# ...
#   Attempting uninstall: jupyterlab_rise
#     Found existing installation: jupyterlab_rise 0.3.0
#     Uninstalling jupyterlab_rise-0.3.0:
#       Successfully uninstalled jupyterlab_rise-0.3.0
# ...
# Note: you may need to restart the kernel to use updated packages.
